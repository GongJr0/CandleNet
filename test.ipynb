# %%
from CandleNet.DataAccess import TickerAccessor
from CandleNet import TickerContainer, IndexContainer, combine_index
import pandas as pd

# %%
idx = IndexContainer(
    index="GSPC",
    period="1y",
    interval="1d"
)
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 1 Failed download:
# ['AEP']: Timeout('Failed to perform, curl: (28) Connection timed out after 10014 milliseconds. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')

# %%
idx._data
# Out:
# Ticker            AAPL        AMGN        AMZN         AXP          BA  \
# Price            Close       Close       Close       Close       Close
# Date
# 2024-08-20  225.460693  320.498901  178.880005  250.362991  172.100006
# 2024-08-21  225.351212  321.084167  180.110001  243.655777  173.429993
# 2024-08-22  223.489883  316.577393  176.130005  245.100098  172.759995
# 2024-08-23  225.789169  320.742737  177.039993  248.602097  174.960007
# 2024-08-26  226.127594  318.772278  175.500000  251.154404  173.479996
# ...                ...         ...         ...         ...         ...
# 2025-08-13  233.330002  289.329987  224.559998  306.869995  233.369995
# 2025-08-14  232.779999  290.290009  230.979996  307.730011  233.190002
# 2025-08-15  231.589996  296.470001  231.029999  305.470001  235.259995
# 2025-08-18  230.889999  292.619995  231.490005  307.049988  232.410004
# 2025-08-19  230.559998  295.549988  228.009995  306.100006  225.000000
#
# ...

# %%
idx.nameless_data
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2024-08-20  225.460693  226.117640  224.405606  224.724131  30299000
# 2024-08-21  225.351212  226.923894  224.007474  225.470666  34765500
# 2024-08-22  223.489883  227.282232  222.862797  226.734776  43695300
# 2024-08-23  225.789169  227.162781  223.290802  224.614643  38677300
# 2024-08-26  226.127594  226.227137  222.852841  225.709541  30602200
# ...                ...         ...         ...         ...       ...
# 2025-08-13  100.754669  102.570428  100.614996  101.911970  19398500
# 2025-08-14  100.614998  101.203627  100.485304  100.984138  10858400
# 2025-08-15  100.000000  100.769997   99.540001  100.629997  13604900
# 2025-08-18  100.699997  100.879997   99.919998  100.000000  11656100
# 2025-08-19  101.290001  102.425003  100.809998  100.959999  12999374
#
# [7500 rows x 5 columns]

# %%
import datetime as dt

dt.datetime.now().isoformat()
# Out:
# '2025-08-21T13:58:06.821080'
