# %%
import pandas as pd
import yfinance as yf
from CandleNet.DataAccess import TickerAccessor

# %%
TickerAccessor.get_index("GSPC", period="1mo", interval="1d")
# Out:
# C:\Users\guney\Documents\GitHub\CandleNet\CandleNet\DataAccess\TickerAccessor.py:101: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   return yf.download(tickers, start=start, end=end, period=period, interval=interval)
# [*********************100%***********************]  503 of 503 completed
# Price            Close                                                  \
# Ticker               A        AAPL        ABBV        ABNB         ABT
# Date
# 2025-07-15  112.940002  208.872955  186.389999  136.539993  131.490005
# 2025-07-16  113.430000  209.921768  190.580002  136.710007  131.740005
# 2025-07-17  116.360001  209.781921  191.399994  139.300003  120.510002
# 2025-07-18  113.989998  210.940598  189.259995  139.339996  123.669998
# 2025-07-21  112.040001  212.239120  184.850006  138.070007  124.419998
# 2025-07-22  116.190002  214.156952  187.110001  139.429993  125.730003
# 2025-07-23  119.470001  213.907227  190.550003  139.830002  125.830002
# ...

# %%
url = 'https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average'
pd.read_html(url)[2]
